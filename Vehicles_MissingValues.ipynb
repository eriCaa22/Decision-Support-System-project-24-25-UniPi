# %%
import csv

with open('Vehicles.csv', mode='r') as file:
    reader = csv.DictReader(file)
    vehicles = [row for row in reader]

# %%
import csv

with open('C:/Users/al797/Desktop/Crashes.csv', mode='r') as file:
    reader = csv.DictReader(file)
    crashes = [row for row in reader]

# %%
vehicles
# Out:
# [{'CRASH_UNIT_ID': '561555',
#   'RD_NO': 'JC113649',
#   'CRASH_DATE': '01/12/2019 12:01:00 AM',
#   'UNIT_NO': '1',
#   'UNIT_TYPE': 'DRIVER',
#   'VEHICLE_ID': '535742.0',
#   'MAKE': 'UNKNOWN',
#   'MODEL': 'UNKNOWN',
#   'LIC_PLATE_STATE': 'XX',
#   'VEHICLE_YEAR': '',
#   'VEHICLE_DEFECT': 'UNKNOWN',
#   'VEHICLE_TYPE': 'UNKNOWN/NA',
#   'VEHICLE_USE': 'UNKNOWN/NA',
#   'TRAVEL_DIRECTION': 'S',
#   'MANEUVER': 'STRAIGHT AHEAD',
#   'OCCUPANT_CNT': '1.0',
#   'FIRST_CONTACT_POINT': 'REAR-RIGHT'},
#  {'CRASH_UNIT_ID': '561563',
#   'RD_NO': 'JC113627',
#   'CRASH_DATE': '01/11/2019 11:36:00 PM',
#   'UNIT_NO': '2',
#   'UNIT_TYPE': 'DRIVER',
#   'VEHICLE_ID': '535738.0',
#   'MAKE': 'TOYOTA MOTOR COMPANY, LTD.',
#   'MODEL': 'Highlander(beginning vehicle year 2001)',
#   'LIC_PLATE_STATE': 'IL',
#   'VEHICLE_YEAR': '2003.0',
#   'VEHICLE_DEFECT': 'NONE',
#   'VEHICLE_TYPE': 'SPORT UTILITY VEHICLE (SUV)',
#   'VEHICLE_USE': 'PERSONAL',
#   'TRAVEL_DIRECTION': 'S',
# ...

# %% [markdown]
# #### MISSING VALUES
#
# UNIT_TYPE 1
#
# VEHICLE_ID 10373    (tutti pedoni/bici)
#
# MAKE 10373          (tutti pedoni/bici)
#
# MODEL 11786
#
# LIC_PLATE_STATE 49629
#
# VEHICLE_YEAR 88655
#
# VEHICLE_DEFECT 10373    (tutti pedoni/bici)
#
# VEHICLE_TYPE 10373  (tutti pedoni/bici)
#
# VEHICLE_USE 10373   (tutti pedoni/bici)
#
# TRAVEL_DIRECTION 10373  (tutti pedoni/bici)
#
# MANEUVER 10373  (tutti pedoni/bici)
#
# OCCUPANT_CNT 10373  (tutti pedoni/bici)
#
# FIRST_CONTACT_POINT 10388   (tutti pedoni/bici tranne le ultime 15 per le quali possiamo risalire al first concatc point)

# %%
def replace_nulls(ds, column_name, replacement_value):
    
    for record in ds:
        value = record[column_name].strip().lower() if record[column_name] else None
        
        if value in [None, "", "null", "none"]:
            record[column_name] = replacement_value

# %%
def replace_nulls_with_conditions(ds, column_name_to_check, target_value, column_to_replace, replacement_value):
    
    for record in ds:
        if record[column_name_to_check] == target_value and not record[column_to_replace]:
            record[column_to_replace] = replacement_value

# %%
def mv_count(variable):
    count = 0 
    for record in vehicles:
        if not record[variable]:
            count += 1
    return count

# %% [markdown]
# ### UNIT_TYPE
# Controllando RD_NO del ds crashes possiamo vedere come l'unico soggetto interessato all'incidente sia lo stesso che lo ha causato; inolte, il tipo di scontro è definito come pedocyclist per questo lo sostituiamo con bicycle

# %%
for vehicle in vehicles:
    if vehicle['UNIT_TYPE'] == 'Nan':
        vehicle['UNIT_TYPE'] = 'BICYCLE'

# %%
replace_nulls(vehicles, 'UNIT_TYPE', 'BICYCLE')

# %%
mv_count('UNIT_TYPE')
# Out:
# 0

# %% [markdown]
# ### VEHICLE_ID
# Sono tutti pedoni o ciclisti tranne 49 che sono NON-CONCTACT VEHILCE, qualche DRIVERS e alcuni Nan

# %%
mv_count('VEHICLE_ID')

# %%
replace_nulls(vehicles, 'VEHICLE_ID', -1.0)

# %%
mv_count('VEHICLE_ID')
# Out:
# 10325

# %% [markdown]
# ### MAKE

# %%
mv_count('MAKE')
# Out:
# 10373

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'MAKE', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'MAKE', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'MAKE', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'MAKE', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'MAKE', 'UNKNOWN')

# %%
mv_count('MAKE')
# Out:
# 0

# %% [markdown]
# ### MODEL

# %%
mv_count('MODEL')
# Out:
# 11786

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'MODEL', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'MODEL', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'MODEL', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'MODEL', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'MODEL', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PARKED', 'MODEL', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVERLESS', 'MODEL', 'UNKNOWN')

# %%
mv_count('MODEL')
# Out:
# 0

# %% [markdown]
# ### LIC_PLATE_STATE

# %%
mv_count('LIC_PLATE_STATE')
# Out:
# 49629

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'LIC_PLATE_STATE', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'LIC_PLATE_STATE', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'LIC_PLATE_STATE', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'LIC_PLATE_STATE', 'XX')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'LIC_PLATE_STATE', 'XX')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PARKED', 'LIC_PLATE_STATE', 'XX') 
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVERLESS', 'LIC_PLATE_STATE', 'XX')

# %%
mv_count('LIC_PLATE_STATE')
# Out:
# 0

# %% [markdown]
# ### VEHICLE_YEAR

# %%
mv_count('VEHICLE_YEAR')
# Out:
# 88655

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'VEHICLE_YEAR', -1)

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'VEHICLE_YEAR', -1)

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'VEHICLE_YEAR', -1)

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'VEHICLE_YEAR', -1)

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'VEHICLE_YEAR', -1)

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PARKED', 'VEHICLE_YEAR', -1)
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVERLESS', 'VEHICLE_YEAR', -1)

# %%
mv_count('VEHICLE_YEAR')
# Out:
# 0

# %% [markdown]
# ### VEHICLE_DEFECT
# Ho continuato con la sostituzione fatta fino ad ora, ma guardando la distribuzione si vede che per 27000 è NONE, per altri 17000 UKNOWN, non so se è meglio sostituire con quelli o no.

# %%
mv_count('VEHICLE_DEFECT')
# Out:
# 10373

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'VEHICLE_DEFECT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'VEHICLE_DEFECT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'VEHICLE_DEFECT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'VEHICLE_DEFECT', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'VEHICLE_DEFECT', 'UNKNOWN')

# %%
mv_count('VEHICLE_DEFECT')
# Out:
# 0

# %% [markdown]
# ### VEHICLE_TYPE
# Ho aggiiunto la categoria "NON-MOTOR VEHICLE" per i  pedoni, bici e veicoli non a motore. Per il driver ho messo SUV che è la categoria più comune, per i non contact vehicle ho messo UNKNOWN.

# %%
mv_count('VEHICLE_TYPE')
# Out:
# 10373

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'VEHICLE_TYPE', 'UNKNOWN/NA')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'VEHICLE_TYPE', 'UNKNOWN/NA')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'VEHICLE_TYPE', 'UNKNOWN/NA')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'VEHICLE_TYPE', 'UNKNOWN/NA')

# %% [markdown]
# Per i driver, siccome sono solo 6, usiamo la moda

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'VEHICLE_TYPE', 'SPORT UTILITY VEHICLE (SUV)')

# %%
mv_count('VEHICLE_TYPE')
# Out:
# 0

# %% [markdown]
# ### VEHICLE_USE
# Ho deciso di mantenere la proporzione con cui si presentano le maggiori due categorie: PERSONAL (67%) e UNKNOWN (20%)

# %%
mv_count('VEHICLE_USE')
# Out:
# 10373

# %%
replace_nulls(vehicles, 'UNIT_TYPE', 'UNKNOWN/NA')

# %%
mv_count('VEHICLE_USE')
# Out:
# 0

# %% [markdown]
# ### TRAVEL_DIRECTION
# sostituitui i valori di travel direction con quelli di street direction che si trovano su crashes

# %%
mv_count('TRAVEL_DIRECTION')
# Out:
# 10373

# %%
replace_nulls(vehicles, 'TRAVEL_DIRECTION', 'UNKNOWN')

# %%
mv_count('TRAVEL_DIRECTION')
# Out:
# 0

# %% [markdown]
# ### MANEUVER

# %%
mv_count('MANEUVER')
# Out:
# 10373

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'MANEUVER', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'MANEUVER', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'MANEUVER', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'MANEUVER', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'MANEUVER', 'UNKNOWN')

# %%
mv_count('MANEUVER')
# Out:
# 0

# %% [markdown]
# ### OCCUPANT_CNT

# %%
mv_count('OCCUPANT_CNT')
# Out:
# 10373

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'OCCUPANT_CNT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'OCCUPANT_CNT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'OCCUPANT_CNT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'OCCUPANT_CNT', 'UNKNOWN')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'OCCUPANT_CNT', 'UNKNOWN')

# %%
mv_count('OCCUPANT_CNT')
# Out:
# 0

# %% [markdown]
# ### FIRST_CONTACT_POINT

# %%
mv_count('FIRST_CONTACT_POINT')
# Out:
# 10388

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'PEDESTRIAN', 'FIRST_CONTACT_POINT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'BICYCLE', 'FIRST_CONTACT_POINT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-MOTOR VEHICLE', 'FIRST_CONTACT_POINT', 'NOT APPLICABLE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'NON-CONTACT VEHICLE', 'FIRST_CONTACT_POINT', 'NONE')

# %%
replace_nulls_with_conditions(vehicles, 'UNIT_TYPE', 'DRIVER', 'FIRST_CONTACT_POINT', 'UNKNOWN')

# %%
mv_count('FIRST_CONTACT_POINT')
# Out:
# 0

# %%
import csv

fieldnames = vehicles[0].keys()

with open('C:/Users/al797/DSS LAB/cleaned_vehicles.csv', mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(vehicles)
